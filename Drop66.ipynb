# %% [markdown]
# <a href="https://colab.research.google.com/github/33Surya66/33Surya66/blob/main/Drop66.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path="/content/drive/MyDrive/9Edit.csv"
df=pd.read_csv(path)
df
# Out:
#       Marital status  Course  Daytime/evening attendance\t  \
# 0                  1     171                             1
# 1                  1    9070                             1
# 2                  1    9254                             1
# 3                  1    9238                             1
# 4                  1    9853                             1
# ...              ...     ...                           ...
# 1416               2    9773                             1
# 1417               1    9130                             1
# 1418               4    9500                             1
# 1419               1    9773                             1
# 1420               1    9500                             1
#
#       Previous qualification  Previous qualification (grade)    GPA  \
# 0                          1                           122.0  12.20
# 1                          1                           122.0  12.20
# ...

# %%
df.dtypes
# Out:
# Marital status                        int64
# Course                                int64
# Daytime/evening attendance\t          int64
# Previous qualification                int64
# Previous qualification (grade)      float64
# GPA                                 float64
# Admission grade                     float64
# Displaced                             int64
# Educational special needs             int64
# Debtor                                int64
# Tuition fees up to date               int64
# Gender                               object
# Curricular units 1st sem (grade)    float64
# Curricular units 2nd sem (grade)    float64
# Target                               object
# Region                               object
# dtype: object

# %%
df.describe()
# Out:
#        Marital status       Course  Daytime/evening attendance\t  \
# count     1421.000000  1421.000000                   1421.000000
# mean         1.261084  8755.629838                      0.854328
# std          0.721958  2278.779477                      0.352901
# min          1.000000    33.000000                      0.000000
# 25%          1.000000  9085.000000                      1.000000
# 50%          1.000000  9238.000000                      1.000000
# 75%          1.000000  9670.000000                      1.000000
# max          6.000000  9991.000000                      1.000000
#
#        Previous qualification  Previous qualification (grade)          GPA  \
# count             1421.000000                     1421.000000  1421.000000
# mean                 5.311049                      131.114075    13.111407
# std                 10.309934                       12.873354     1.287335
# min                  1.000000                       95.000000     9.500000
# ...

# %%
df.columns
# Out:
# Index(['Marital status', 'Course', 'Daytime/evening attendance\t',
#        'Previous qualification', 'Previous qualification (grade)', 'GPA',
#        'Admission grade', 'Displaced', 'Educational special needs', 'Debtor',
#        'Tuition fees up to date', 'Gender', 'Curricular units 1st sem (grade)',
#        'Curricular units 2nd sem (grade)', 'Target', 'Region'],
#       dtype='object')

# %%
df.isnull()
# Out:
#       Marital status  Course  Daytime/evening attendance\t  \
# 0              False   False                         False
# 1              False   False                         False
# 2              False   False                         False
# 3              False   False                         False
# 4              False   False                         False
# ...              ...     ...                           ...
# 1416           False   False                         False
# 1417           False   False                         False
# 1418           False   False                         False
# 1419           False   False                         False
# 1420           False   False                         False
#
#       Previous qualification  Previous qualification (grade)    GPA  \
# 0                      False                           False  False
# 1                      False                           False  False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1421 entries, 0 to 1420
# Data columns (total 16 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Marital status                    1421 non-null   int64
#  1   Course                            1421 non-null   int64
#  2   Daytime/evening attendance	       1421 non-null   int64
#  3   Previous qualification            1421 non-null   int64
#  4   Previous qualification (grade)    1421 non-null   float64
#  5   GPA                               1421 non-null   float64
#  6   Admission grade                   1421 non-null   float64
#  7   Displaced                         1421 non-null   int64
#  8   Educational special needs         1421 non-null   int64
#  9   Debtor                            1421 non-null   int64
#  10  Tuition fees up to date           1421 non-null   int64
# ...

# %%
df.hist(figsize=(40,30))
# Out:
# array([[<Axes: title={'center': 'Marital status'}>,
#         <Axes: title={'center': 'Course'}>,
#         <Axes: title={'center': 'Daytime/evening attendance\t'}>,
#         <Axes: title={'center': 'Previous qualification'}>],
#        [<Axes: title={'center': 'Previous qualification (grade)'}>,
#         <Axes: title={'center': 'GPA'}>,
#         <Axes: title={'center': 'Admission grade'}>,
#         <Axes: title={'center': 'Displaced'}>],
#        [<Axes: title={'center': 'Educational special needs'}>,
#         <Axes: title={'center': 'Debtor'}>,
#         <Axes: title={'center': 'Tuition fees up to date'}>,
#         <Axes: title={'center': 'Curricular units 1st sem (grade)'}>],
#        [<Axes: title={'center': 'Curricular units 2nd sem (grade)'}>,
#         <Axes: >, <Axes: >, <Axes: >]], dtype=object)
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 9 (	) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
sb.pairplot(df,hue="Debtor", diag_kind="hist")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 9 (	) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:80: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 9 (	) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df.count()
# Out:
# Marital status                      1421
# Course                              1421
# Daytime/evening attendance\t        1421
# Previous qualification              1421
# Previous qualification (grade)      1421
# GPA                                 1421
# Admission grade                     1421
# Displaced                           1421
# Educational special needs           1421
# Debtor                              1421
# Tuition fees up to date             1421
# Gender                              1421
# Curricular units 1st sem (grade)    1421
# Curricular units 2nd sem (grade)    1421
# Target                              1421
# Region                              1421
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#       Marital status  Course  Daytime/evening attendance\t  \
# 0                  1     171                             1
# 1                  1    9070                             1
# 2                  1    9254                             1
# 3                  1    9238                             1
# 4                  1    9853                             1
# ...              ...     ...                           ...
# 1416               2    9773                             1
# 1417               1    9130                             1
# 1418               4    9500                             1
# 1419               1    9773                             1
# 1420               1    9500                             1
#
#       Previous qualification  Previous qualification (grade)    GPA  \
# 0                          1                           122.0  12.20
# 1                          1                           122.0  12.20
# ...

# %%
plt.figure(figsize=(30,20))
d=df.corr()
sb.heatmap(d,cmap="autumn",annot=True)
d
# Out:
# <ipython-input-36-eb1074e5eaa7>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   d=df.corr()
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:80: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.draw()
#                                   Marital status    Course  \
# Marital status                          1.000000  0.072212
# Course                                  0.072212  1.000000
# Daytime/evening attendance\t           -0.176777 -0.101016
# Previous qualification                  0.073286  0.016213
# Previous qualification (grade)          0.005030 -0.070478
# GPA                                     0.005030 -0.070478
# Admission grade                         0.010476 -0.074778
# Displaced                              -0.225954 -0.108104
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix as conf
from sklearn.metrics import accuracy_score as acc

# %%
from sklearn.metrics import classification_report
